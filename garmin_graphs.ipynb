# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./activities.csv')

# %%
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Start Time                             41 non-null     object
#  1   End Time                               41 non-null     object
#  2   Activity ID                            41 non-null     int64
#  3   Activity Name                          41 non-null     object
#  4   Description                            0 non-null      float64
#  5   Location Name                          37 non-null     object
#  6   Time Zone                              41 non-null     object
#  7   Offset                                 41 non-null     object
#  8   Duration (h:m:s)                       41 non-null     object
#  9   Elapsed Duration (h:m:s)               41 non-null     object
# ...

# %%
# Use columns:
#   Average Heart Rate (bpm) - aggregate heart rate over the span of activities and see how it changes
#   VO2max
#   Calories
#   Duration (h:m:s)
#  Maybe compare some sort of time/distance metric(?)

# %%
plt.scatter(df['Duration (h:m:s)'], df['Average Heart Rate (bpm)'])
plt.xlabel('Duration')
plt.ylabel('Average Heart Rate')
plt.title('Average Heart Rate vs. Activity Duration')
plt.show()
